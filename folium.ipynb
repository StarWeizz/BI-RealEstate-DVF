# %%
# !pip install folium
# Out:
# Collecting folium
#   Using cached folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting branca>=0.6.0 (from folium)
#   Using cached branca-0.8.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting jinja2>=2.9 (from folium)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy in c:\users\dell g5 5590\documents\ynov\2025\yboost\realestate\venv\lib\site-packages (from folium) (2.3.5)
# Requirement already satisfied: requests in c:\users\dell g5 5590\documents\ynov\2025\yboost\realestate\venv\lib\site-packages (from folium) (2.32.5)
# Collecting xyzservices (from folium)
#   Using cached xyzservices-2025.11.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting MarkupSafe>=2.0 (from jinja2>=2.9->folium)
#   Using cached markupsafe-3.0.3-cp314-cp314-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell g5 5590\documents\ynov\2025\yboost\realestate\venv\lib\site-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell g5 5590\documents\ynov\2025\yboost\realestate\venv\lib\site-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell g5 5590\documents\ynov\2025\yboost\realestate\venv\lib\site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell g5 5590\documents\ynov\2025\yboost\realestate\venv\lib\site-packages (from requests->folium) (2025.11.12)
# Using cached folium-0.20.0-py2.py3-none-any.whl (113 kB)
# Using cached branca-0.8.2-py3-none-any.whl (26 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp314-cp314-win_amd64.whl (15 kB)
# Using cached xyzservices-2025.11.0-py3-none-any.whl (93 kB)
# Installing collected packages: xyzservices, MarkupSafe, jinja2, branca, folium
#
#    ---------------- ----------------------- 2/5 [jinja2]
#    ---------------- ----------------------- 2/5 [jinja2]
#    ---------------- ----------------------- 2/5 [jinja2]
#    ------------------------ --------------- 3/5 [branca]
#    -------------------------------- ------- 4/5 [folium]
#    -------------------------------- ------- 4/5 [folium]
#    -------------------------------- ------- 4/5 [folium]
#    ---------------------------------------- 5/5 [folium]
#
# Successfully installed MarkupSafe-3.0.3 branca-0.8.2 folium-0.20.0 jinja2-3.1.6 xyzservices-2025.11.0
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import folium

code_commune = 75119

def fetch(codeC):
    response = requests.get(f"http://api.cquest.org/dvf?code_commune={codeC}")
    return response.json()

data = fetch(code_commune)

# On récupère les coordonnées valides
points = []
for item in data.get("resultats", []):
    lat = item.get("lat")
    lon = item.get("lon")
    
    # On ne garde que si les valeurs existent et sont numeriques
    if lat is not None and lon is not None:
        points.append((float(lat), float(lon)))

# Si on a au moins un bien, on centre la carte dessus
if points:
    center = points[0]
else:
    center = (48.8566, 2.3522)  # fallback Paris

m = folium.Map(location=center, zoom_start=13)

# Ajout des marqueurs uniquement pour les points valides
for lat, lon in points:
    folium.Marker(
        location=[lat, lon],
        tooltip="Bien DVF",
        icon=folium.Icon(color="blue"),
    ).add_to(m)

m.save("test.html")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\DELL G5 5590\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\DELL G5 5590\AppData\Local\Programs\Python\Python314\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\DELL G5 5590\AppData\Local\Programs\Python\Python314\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File c:\Users\DELL G5 5590\AppData\Local\Programs\Python\Python314\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[1], line 10
#       7     response = requests.get(f"http://api.cquest.org/dvf?code_commune={codeC}")
#       8     return response.json()
# ---> 10 data = fetch(code_commune)
#      12 # On récupère les coordonnées valides
#      13 points = []
#
# Cell In[1], line 8, in fetch(codeC)
#       6 def fetch(codeC):
#       7     response = requests.get(f"http://api.cquest.org/dvf?code_commune={codeC}")
# ----> 8     return response.json()
#
# File c:\Users\DELL G5 5590\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
